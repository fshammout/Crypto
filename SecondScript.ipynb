# %%
# import the libraries
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from pycaret.regression import *
import pandas_datareader.data as pdr
import datetime as dt
import yfinance as yf
yf.pdr_override()

# %%
crypto_currency = 'BTC'
against_currency = 'USD'

start = dt.datetime(2020, 1, 1)
end = dt.datetime.now()

data = pdr.get_data_yahoo(f'{crypto_currency}-{against_currency}', start=start, end=end)
data = data.reset_index()
data
# Out:
# [*********************100%***********************]  1 of 1 completed
#                           Date          Open          High           Low  \
# 0    2020-01-01 00:00:00+00:00   7194.892090   7254.330566   7174.944336
# 1    2020-01-02 00:00:00+00:00   7202.551270   7212.155273   6935.270020
# 2    2020-01-03 00:00:00+00:00   6984.428711   7413.715332   6914.996094
# 3    2020-01-04 00:00:00+00:00   7345.375488   7427.385742   7309.514160
# 4    2020-01-05 00:00:00+00:00   7410.451660   7544.497070   7400.535645
# ...                        ...           ...           ...           ...
# 1128 2023-02-02 00:00:00+00:00  23720.824219  24167.210938  23468.595703
# 1129 2023-02-03 00:00:00+00:00  23469.412109  23678.103516  23279.955078
# 1130 2023-02-04 00:00:00+00:00  23446.320312  23556.949219  23291.794922
# 1131 2023-02-05 00:00:00+00:00  23332.248047  23423.435547  22841.759766
# 1132 2023-02-06 00:00:00+00:00  22959.066406  23078.000000  22734.601562
#
#              Close     Adj Close       Volume
# 0      7200.174316   7200.174316  18565664997
# 1      6985.470215   6985.470215  20802083465
# 2      7344.884277   7344.884277  28111481032
# 3      7410.656738   7410.656738  18444271275
# 4      7411.317383   7411.317383  19725074095
# ...            ...           ...          ...
# 1128  23471.871094  23471.871094  32066936882
# 1129  23449.322266  23449.322266  27083066007
# 1130  23331.847656  23331.847656  15639298538
# 1131  22955.666016  22955.666016  19564262605
# 1132  22871.025391  22871.025391  22702934016
#
# [1133 rows x 7 columns]

# %%
#A variable for predicting one day into the future
future_days = 1
#Create a new column (the target or dependent variable) shifted 'n' units up, in this case n=1

data['Future_Price'] = data[['Close']].shift(-future_days)
#Choose the columns to keep

data = data[['Close', 'Future_Price']]
#show new data
data
# Out:
#              Close  Future_Price
# 0      7200.174316   6985.470215
# 1      6985.470215   7344.884277
# 2      7344.884277   7410.656738
# 3      7410.656738   7411.317383
# 4      7411.317383   7769.219238
# ...            ...           ...
# 1128  23471.871094  23449.322266
# 1129  23449.322266  23331.847656
# 1130  23331.847656  22955.666016
# 1131  22955.666016  22871.025391
# 1132  22871.025391           NaN
#
# [1133 rows x 2 columns]

# %%
#Make a copy of the dataset
df = data.copy()

#Crete the independent dataset
X = np.array(df[df.columns])

#Remove the last 'n' rows from the dataset where the 'n' is the future_days=1
X = X[:len(data)-future_days]

#Create the dependent dataset (y) and convert the  dataframe to a numpy array
y = np.array(df['Future_Price'])

#Get all of the y values except for the last 'n' rows which is the future_days=1
y = y[:-future_days]

#Split the dataset into 85% training and 15% testing sets
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.15, random_state=0, shuffle=False)

# %%
#Get the train data and transform it into dataframe
train_data = pd.DataFrame(x_train, columns=df.columns)

#Show the first 7 rows of the data
train_data.head(7)
# Out:
#          Close  Future_Price
# 0  7200.174316   6985.470215
# 1  6985.470215   7344.884277
# 2  7344.884277   7410.656738
# 3  7410.656738   7411.317383
# 4  7411.317383   7769.219238
# 5  7769.219238   8163.692383
# 6  8163.692383   8079.862793

# %%
#get the test data and transform it into a dataframe
test_data = pd.DataFrame(x_test, columns=df.columns)

#Show the first 7 rows of the test data
test_data.head(7)
# Out:
#           Close  Future_Price
# 0  21166.060547  21534.121094
# 1  21534.121094  21398.908203
# 2  21398.908203  21528.087891
# 3  21528.087891  21395.019531
# 4  21395.019531  21600.904297
# 5  21600.904297  20260.019531
# 6  20260.019531  20041.738281

# %%
#Initializes the setup
regression_setup = setup(data=train_data, target='Future_Price', session_id= 123, use_gpu=True)
# Out:
# <style type="text/css">
# #T_38aa9_row8_col1, #T_38aa9_row15_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_38aa9">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_38aa9_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_38aa9_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_38aa9_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_38aa9_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_38aa9_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_38aa9_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_38aa9_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_38aa9_row1_col1" class="data row1 col1" >Future_Price</td>
#     </tr>
#     <tr>
#       <th id="T_38aa9_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_38aa9_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_38aa9_row2_col1" class="data row2 col1" >Regression</td>
#     </tr>
#     <tr>
#       <th id="T_38aa9_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_38aa9_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_38aa9_row3_col1" class="data row3 col1" >(962, 2)</td>
#     </tr>
#     <tr>
#       <th id="T_38aa9_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_38aa9_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_38aa9_row4_col1" class="data row4 col1" >(962, 2)</td>
#     </tr>
#     <tr>
#       <th id="T_38aa9_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_38aa9_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_38aa9_row5_col1" class="data row5 col1" >(673, 2)</td>
#     </tr>
#     <tr>
#       <th id="T_38aa9_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_38aa9_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_38aa9_row6_col1" class="data row6 col1" >(289, 2)</td>
#     </tr>
#     <tr>
#       <th id="T_38aa9_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_38aa9_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_38aa9_row7_col1" class="data row7 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_38aa9_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_38aa9_row8_col0" class="data row8 col0" >Preprocess</td>
#       <td id="T_38aa9_row8_col1" class="data row8 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_38aa9_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_38aa9_row9_col0" class="data row9 col0" >Imputation type</td>
#       <td id="T_38aa9_row9_col1" class="data row9 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_38aa9_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_38aa9_row10_col0" class="data row10 col0" >Numeric imputation</td>
#       <td id="T_38aa9_row10_col1" class="data row10 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_38aa9_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_38aa9_row11_col0" class="data row11 col0" >Categorical imputation</td>
#       <td id="T_38aa9_row11_col1" class="data row11 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_38aa9_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_38aa9_row12_col0" class="data row12 col0" >Fold Generator</td>
#       <td id="T_38aa9_row12_col1" class="data row12 col1" >KFold</td>
#     </tr>
#     <tr>
#       <th id="T_38aa9_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_38aa9_row13_col0" class="data row13 col0" >Fold Number</td>
#       <td id="T_38aa9_row13_col1" class="data row13 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_38aa9_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_38aa9_row14_col0" class="data row14 col0" >CPU Jobs</td>
#       <td id="T_38aa9_row14_col1" class="data row14 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_38aa9_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_38aa9_row15_col0" class="data row15 col0" >Use GPU</td>
#       <td id="T_38aa9_row15_col1" class="data row15 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_38aa9_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_38aa9_row16_col0" class="data row16 col0" >Log Experiment</td>
#       <td id="T_38aa9_row16_col1" class="data row16 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_38aa9_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_38aa9_row17_col0" class="data row17 col0" >Experiment Name</td>
#       <td id="T_38aa9_row17_col1" class="data row17 col1" >reg-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_38aa9_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_38aa9_row18_col0" class="data row18 col0" >USI</td>
#       <td id="T_38aa9_row18_col1" class="data row18 col1" >120e</td>
#     </tr>
#   </tbody>
# </table>

# %%
#Train on all of the models and sort them by the R-squared metric aka (r2) and then store the model with the highest R-squared value
best_model = compare_models()
# Out:
# <style type="text/css">
# #T_ab0be th {
#   text-align: left;
# }
# #T_ab0be_row0_col0, #T_ab0be_row0_col1, #T_ab0be_row0_col2, #T_ab0be_row0_col3, #T_ab0be_row0_col5, #T_ab0be_row0_col6, #T_ab0be_row1_col0, #T_ab0be_row1_col1, #T_ab0be_row1_col2, #T_ab0be_row1_col3, #T_ab0be_row1_col5, #T_ab0be_row1_col6, #T_ab0be_row2_col0, #T_ab0be_row2_col1, #T_ab0be_row2_col2, #T_ab0be_row2_col3, #T_ab0be_row2_col5, #T_ab0be_row2_col6, #T_ab0be_row3_col0, #T_ab0be_row3_col1, #T_ab0be_row3_col2, #T_ab0be_row3_col3, #T_ab0be_row3_col5, #T_ab0be_row3_col6, #T_ab0be_row4_col0, #T_ab0be_row4_col1, #T_ab0be_row4_col2, #T_ab0be_row4_col3, #T_ab0be_row4_col5, #T_ab0be_row4_col6, #T_ab0be_row5_col0, #T_ab0be_row6_col0, #T_ab0be_row6_col1, #T_ab0be_row6_col2, #T_ab0be_row6_col3, #T_ab0be_row6_col5, #T_ab0be_row6_col6, #T_ab0be_row7_col0, #T_ab0be_row7_col1, #T_ab0be_row7_col2, #T_ab0be_row7_col3, #T_ab0be_row7_col5, #T_ab0be_row7_col6, #T_ab0be_row8_col0, #T_ab0be_row8_col1, #T_ab0be_row8_col2, #T_ab0be_row8_col3, #T_ab0be_row8_col5, #T_ab0be_row8_col6, #T_ab0be_row9_col0, #T_ab0be_row9_col1, #T_ab0be_row9_col2, #T_ab0be_row9_col3, #T_ab0be_row9_col4, #T_ab0be_row9_col5, #T_ab0be_row9_col6, #T_ab0be_row10_col0, #T_ab0be_row10_col1, #T_ab0be_row10_col2, #T_ab0be_row10_col3, #T_ab0be_row10_col4, #T_ab0be_row10_col5, #T_ab0be_row10_col6, #T_ab0be_row11_col0, #T_ab0be_row11_col1, #T_ab0be_row11_col2, #T_ab0be_row11_col3, #T_ab0be_row11_col4, #T_ab0be_row11_col5, #T_ab0be_row11_col6, #T_ab0be_row12_col0, #T_ab0be_row12_col1, #T_ab0be_row12_col2, #T_ab0be_row12_col3, #T_ab0be_row12_col4, #T_ab0be_row12_col5, #T_ab0be_row12_col6, #T_ab0be_row13_col0, #T_ab0be_row13_col1, #T_ab0be_row13_col2, #T_ab0be_row13_col3, #T_ab0be_row13_col4, #T_ab0be_row13_col5, #T_ab0be_row13_col6, #T_ab0be_row14_col0, #T_ab0be_row14_col1, #T_ab0be_row14_col2, #T_ab0be_row14_col3, #T_ab0be_row14_col4, #T_ab0be_row14_col5, #T_ab0be_row14_col6, #T_ab0be_row15_col0, #T_ab0be_row15_col1, #T_ab0be_row15_col2, #T_ab0be_row15_col3, #T_ab0be_row15_col4, #T_ab0be_row15_col5, #T_ab0be_row15_col6, #T_ab0be_row16_col0, #T_ab0be_row16_col1, #T_ab0be_row16_col2, #T_ab0be_row16_col3, #T_ab0be_row16_col4, #T_ab0be_row16_col5, #T_ab0be_row16_col6, #T_ab0be_row17_col0, #T_ab0be_row17_col1, #T_ab0be_row17_col2, #T_ab0be_row17_col3, #T_ab0be_row17_col4, #T_ab0be_row17_col5, #T_ab0be_row17_col6, #T_ab0be_row18_col0, #T_ab0be_row18_col1, #T_ab0be_row18_col2, #T_ab0be_row18_col3, #T_ab0be_row18_col4, #T_ab0be_row18_col5, #T_ab0be_row18_col6 {
#   text-align: left;
# }
# #T_ab0be_row0_col4, #T_ab0be_row1_col4, #T_ab0be_row2_col4, #T_ab0be_row3_col4, #T_ab0be_row4_col4, #T_ab0be_row5_col1, #T_ab0be_row5_col2, #T_ab0be_row5_col3, #T_ab0be_row5_col4, #T_ab0be_row5_col5, #T_ab0be_row5_col6, #T_ab0be_row6_col4, #T_ab0be_row7_col4, #T_ab0be_row8_col4 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_ab0be_row0_col7, #T_ab0be_row1_col7, #T_ab0be_row2_col7, #T_ab0be_row3_col7, #T_ab0be_row4_col7, #T_ab0be_row5_col7, #T_ab0be_row6_col7, #T_ab0be_row7_col7, #T_ab0be_row8_col7, #T_ab0be_row9_col7, #T_ab0be_row10_col7, #T_ab0be_row11_col7, #T_ab0be_row12_col7, #T_ab0be_row13_col7, #T_ab0be_row14_col7, #T_ab0be_row15_col7, #T_ab0be_row16_col7, #T_ab0be_row17_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_ab0be_row18_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_ab0be">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ab0be_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_ab0be_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_ab0be_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_ab0be_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_ab0be_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_ab0be_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_ab0be_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_ab0be_level0_col7" class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ab0be_level0_row0" class="row_heading level0 row0" >lr</th>
#       <td id="T_ab0be_row0_col0" class="data row0 col0" >Linear Regression</td>
#       <td id="T_ab0be_row0_col1" class="data row0 col1" >882.2790</td>
#       <td id="T_ab0be_row0_col2" class="data row0 col2" >1947982.3062</td>
#       <td id="T_ab0be_row0_col3" class="data row0 col3" >1373.1744</td>
#       <td id="T_ab0be_row0_col4" class="data row0 col4" >0.9939</td>
#       <td id="T_ab0be_row0_col5" class="data row0 col5" >0.0410</td>
#       <td id="T_ab0be_row0_col6" class="data row0 col6" >0.0284</td>
#       <td id="T_ab0be_row0_col7" class="data row0 col7" >0.0410</td>
#     </tr>
#     <tr>
#       <th id="T_ab0be_level0_row1" class="row_heading level0 row1" >llar</th>
#       <td id="T_ab0be_row1_col0" class="data row1 col0" >Lasso Least Angle Regression</td>
#       <td id="T_ab0be_row1_col1" class="data row1 col1" >884.9154</td>
#       <td id="T_ab0be_row1_col2" class="data row1 col2" >1948341.0375</td>
#       <td id="T_ab0be_row1_col3" class="data row1 col3" >1373.5600</td>
#       <td id="T_ab0be_row1_col4" class="data row1 col4" >0.9939</td>
#       <td id="T_ab0be_row1_col5" class="data row1 col5" >0.0412</td>
#       <td id="T_ab0be_row1_col6" class="data row1 col6" >0.0287</td>
#       <td id="T_ab0be_row1_col7" class="data row1 col7" >0.0330</td>
#     </tr>
#     <tr>
#       <th id="T_ab0be_level0_row2" class="row_heading level0 row2" >lasso</th>
#       <td id="T_ab0be_row2_col0" class="data row2 col0" >Lasso Regression</td>
#       <td id="T_ab0be_row2_col1" class="data row2 col1" >882.2788</td>
#       <td id="T_ab0be_row2_col2" class="data row2 col2" >1947981.4062</td>
#       <td id="T_ab0be_row2_col3" class="data row2 col3" >1373.1741</td>
#       <td id="T_ab0be_row2_col4" class="data row2 col4" >0.9939</td>
#       <td id="T_ab0be_row2_col5" class="data row2 col5" >0.0410</td>
#       <td id="T_ab0be_row2_col6" class="data row2 col6" >0.0284</td>
#       <td id="T_ab0be_row2_col7" class="data row2 col7" >0.0380</td>
#     </tr>
#     <tr>
#       <th id="T_ab0be_level0_row3" class="row_heading level0 row3" >br</th>
#       <td id="T_ab0be_row3_col0" class="data row3 col0" >Bayesian Ridge</td>
#       <td id="T_ab0be_row3_col1" class="data row3 col1" >882.2943</td>
#       <td id="T_ab0be_row3_col2" class="data row3 col2" >1947981.6312</td>
#       <td id="T_ab0be_row3_col3" class="data row3 col3" >1373.1760</td>
#       <td id="T_ab0be_row3_col4" class="data row3 col4" >0.9939</td>
#       <td id="T_ab0be_row3_col5" class="data row3 col5" >0.0410</td>
#       <td id="T_ab0be_row3_col6" class="data row3 col6" >0.0284</td>
#       <td id="T_ab0be_row3_col7" class="data row3 col7" >0.0270</td>
#     </tr>
#     <tr>
#       <th id="T_ab0be_level0_row4" class="row_heading level0 row4" >omp</th>
#       <td id="T_ab0be_row4_col0" class="data row4 col0" >Orthogonal Matching Pursuit</td>
#       <td id="T_ab0be_row4_col1" class="data row4 col1" >882.2785</td>
#       <td id="T_ab0be_row4_col2" class="data row4 col2" >1947981.6625</td>
#       <td id="T_ab0be_row4_col3" class="data row4 col3" >1373.1742</td>
#       <td id="T_ab0be_row4_col4" class="data row4 col4" >0.9939</td>
#       <td id="T_ab0be_row4_col5" class="data row4 col5" >0.0410</td>
#       <td id="T_ab0be_row4_col6" class="data row4 col6" >0.0284</td>
#       <td id="T_ab0be_row4_col7" class="data row4 col7" >0.0280</td>
#     </tr>
#     <tr>
#       <th id="T_ab0be_level0_row5" class="row_heading level0 row5" >huber</th>
#       <td id="T_ab0be_row5_col0" class="data row5 col0" >Huber Regressor</td>
#       <td id="T_ab0be_row5_col1" class="data row5 col1" >879.6106</td>
#       <td id="T_ab0be_row5_col2" class="data row5 col2" >1945955.7646</td>
#       <td id="T_ab0be_row5_col3" class="data row5 col3" >1371.6450</td>
#       <td id="T_ab0be_row5_col4" class="data row5 col4" >0.9939</td>
#       <td id="T_ab0be_row5_col5" class="data ro

# %%
#Create the model and show its prediction metrics on the training data
model = create_model('huber')
# Out:
# <style type="text/css">
# #T_ba5f8_row10_col0, #T_ba5f8_row10_col1, #T_ba5f8_row10_col2, #T_ba5f8_row10_col3, #T_ba5f8_row10_col4, #T_ba5f8_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_ba5f8">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ba5f8_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_ba5f8_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_ba5f8_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_ba5f8_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_ba5f8_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_ba5f8_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ba5f8_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ba5f8_row0_col0" class="data row0 col0" >774.7646</td>
#       <td id="T_ba5f8_row0_col1" class="data row0 col1" >1358720.7317</td>
#       <td id="T_ba5f8_row0_col2" class="data row0 col2" >1165.6418</td>
#       <td id="T_ba5f8_row0_col3" class="data row0 col3" >0.9962</td>
#       <td id="T_ba5f8_row0_col4" class="data row0 col4" >0.0314</td>
#       <td id="T_ba5f8_row0_col5" class="data row0 col5" >0.0236</td>
#     </tr>
#     <tr>
#       <th id="T_ba5f8_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_ba5f8_row1_col0" class="data row1 col0" >726.5924</td>
#       <td id="T_ba5f8_row1_col1" class="data row1 col1" >1243033.2579</td>
#       <td id="T_ba5f8_row1_col2" class="data row1 col2" >1114.9140</td>
#       <td id="T_ba5f8_row1_col3" class="data row1 col3" >0.9962</td>
#       <td id="T_ba5f8_row1_col4" class="data row1 col4" >0.0340</td>
#       <td id="T_ba5f8_row1_col5" class="data row1 col5" >0.0244</td>
#     </tr>
#     <tr>
#       <th id="T_ba5f8_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_ba5f8_row2_col0" class="data row2 col0" >835.0774</td>
#       <td id="T_ba5f8_row2_col1" class="data row2 col1" >1681305.3780</td>
#       <td id="T_ba5f8_row2_col2" class="data row2 col2" >1296.6516</td>
#       <td id="T_ba5f8_row2_col3" class="data row2 col3" >0.9960</td>
#       <td id="T_ba5f8_row2_col4" class="data row2 col4" >0.0360</td>
#       <td id="T_ba5f8_row2_col5" class="data row2 col5" >0.0254</td>
#     </tr>
#     <tr>
#       <th id="T_ba5f8_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_ba5f8_row3_col0" class="data row3 col0" >687.9011</td>
#       <td id="T_ba5f8_row3_col1" class="data row3 col1" >1030946.2210</td>
#       <td id="T_ba5f8_row3_col2" class="data row3 col2" >1015.3552</td>
#       <td id="T_ba5f8_row3_col3" class="data row3 col3" >0.9961</td>
#       <td id="T_ba5f8_row3_col4" class="data row3 col4" >0.0320</td>
#       <td id="T_ba5f8_row3_col5" class="data row3 col5" >0.0228</td>
#     </tr>
#     <tr>
#       <th id="T_ba5f8_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_ba5f8_row4_col0" class="data row4 col0" >1046.2051</td>
#       <td id="T_ba5f8_row4_col1" class="data row4 col1" >2552189.2475</td>
#       <td id="T_ba5f8_row4_col2" class="data row4 col2" >1597.5573</td>
#       <td id="T_ba5f8_row4_col3" class="data row4 col3" >0.9927</td>
#       <td id="T_ba5f8_row4_col4" class="data row4 col4" >0.0692</td>
#       <td id="T_ba5f8_row4_col5" class="data row4 col5" >0.0362</td>
#     </tr>
#     <tr>
#       <th id="T_ba5f8_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_ba5f8_row5_col0" class="data row5 col0" >982.6643</td>
#       <td id="T_ba5f8_row5_col1" class="data row5 col1" >2084833.9023</td>
#       <td id="T_ba5f8_row5_col2" class="data row5 col2" >1443.8954</td>
#       <td id="T_ba5f8_row5_col3" class="data row5 col3" >0.9933</td>
#       <td id="T_ba5f8_row5_col4" class="data row5 col4" >0.0406</td>
#       <td id="T_ba5f8_row5_col5" class="data row5 col5" >0.0316</td>
#     </tr>
#     <tr>
#       <th id="T_ba5f8_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_ba5f8_row6_col0" class="data row6 col0" >1011.9887</td>
#       <td id="T_ba5f8_row6_col1" class="data row6 col1" >2555912.3510</td>
#       <td id="T_ba5f8_row6_col2" class="data row6 col2" >1598.7221</td>
#       <td id="T_ba5f8_row6_col3" class="data row6 col3" >0.9912</td>
#       <td id="T_ba5f8_row6_col4" class="data row6 col4" >0.0410</td>
#       <td id="T_ba5f8_row6_col5" class="data row6 col5" >0.0285</td>
#     </tr>
#     <tr>
#       <th id="T_ba5f8_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_ba5f8_row7_col0" class="data row7 col0" >1154.4881</td>
#       <td id="T_ba5f8_row7_col1" class="data row7 col1" >3625018.0099</td>
#       <td id="T_ba5f8_row7_col2" class="data row7 col2" >1903.9480</td>
#       <td id="T_ba5f8_row7_col3" class="data row7 col3" >0.9886</td>
#       <td id="T_ba5f8_row7_col4" class="data row7 col4" >0.0526</td>
#       <td id="T_ba5f8_row7_col5" class="data row7 col5" >0.0347</td>
#     </tr>
#     <tr>
#       <th id="T_ba5f8_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_ba5f8_row8_col0" class="data row8 col0" >806.8673</td>
#       <td id="T_ba5f8_row8_col1" class="data row8 col1" >1659629.0229</td>
#       <td id="T_ba5f8_row8_col2" class="data row8 col2" >1288.2659</td>
#       <td id="T_ba5f8_row8_col3" class="data row8 col3" >0.9951</td>
#       <td id="T_ba5f8_row8_col4" class="data row8 col4" >0.0368</td>
#       <td id="T_ba5f8_row8_col5" class="data row8 col5" >0.0276</td>
#     </tr>
#     <tr>
#       <th id="T_ba5f8_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_ba5f8_row9_col0" class="data row9 col0" >769.5566</td>
#       <td id="T_ba5f8_row9_col1" class="data row9 col1" >1667969.5236</td>
#       <td id="T_ba5f8_row9_col2" class="data row9 col2" >1291.4989</td>
#       <td id="T_ba5f8_row9_col3" class="data row9 col3" >0.9938</td>
#       <td id="T_ba5f8_row9_col4" class="data row9 col4" >0.0348</td>
#       <td id="T_ba5f8_row9_col5" class="data row9 col5" >0.0249</td>
#     </tr>
#     <tr>
#       <th id="T_ba5f8_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_ba5f8_row10_col0" class="data row10 col0" >879.6106</td>
#       <td id="T_ba5f8_row10_col1" class="data row10 col1" >1945955.7646</td>
#       <td id="T_ba5f8_row10_col2" class="data row10 col2" >1371.6450</td>
#       <td id="T_ba5f8_row10_col3" class="data row10 col3" >0.9939</td>
#       <td id="T_ba5f8_row10_col4" class="data row10 col4" >0.0408</td>
#       <td id="T_ba5f8_row10_col5" class="data row10 col5" >0.0280</td>
#     </tr>
#     <tr>
#       <th id="T_ba5f8_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_ba5f8_row11_col0" class="data row11 col0" >148.9973</td>
#       <td id="T_ba5f8_row11_col1" class="data row11 col1" >740512.6544</td>
#       <td id="T_ba5f8_row11_col2" class="data row11 col2" >254.0585</td>
#       <td id="T_ba5f8_row11_col3" class="data row11 col3" >0.0024</td>
#       <td id="T_ba5f8_row11_col4" class="data row11 col4" >0.0111</td>
#       <td id="T_ba5f8_row11_col5" class="data row11 col5" >0.0045</td>
#     </tr>
#   </tbody>
# </table>

# %%
#Evaluate the model
evaluate_model(model)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
#Get the predictions
unseen_predictions = predict_model(model, data=test_data)

#Show the predictions
unseen_predictions
# Out:
# <style type="text/css">
# </style>
# <table id="T_41690">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_41690_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_41690_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_41690_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_41690_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_41690_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_41690_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_41690_level0_col6" class="col_heading level0 col6" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_41690_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_41690_row0_col0" class="data row0 col0" >Huber Regressor</td>
#       <td id="T_41690_row0_col1" class="data row0 col1" >334.4935</td>
#       <td id="T_41690_row0_col2" class="data row0 col2" >280968.9539</td>
#       <td id="T_41690_row0_col3" class="data row0 col3" >530.0650</td>
#       <td id="T_41690_row0_col4" class="data row0 col4" >0.9372</td>
#       <td id="T_41690_row0_col5" class="data row0 col5" >0.0276</td>
#       <td id="T_41690_row0_col6" class="data row0 col6" >0.0174</td>
#     </tr>
#   </tbody>
# </table>
#             Close  Future_Price  prediction_label
# 0    21166.060547  21534.121094      21195.459631
# 1    21534.121094  21398.908203      21563.218107
# 2    21398.908203  21528.087891      21428.116187
# 3    21528.087891  21395.019531      21557.189856
# 4    21395.019531  21600.904297      21424.230707
# ..            ...           ...               ...
# 165  23723.769531  23471.871094      23751.069483
# 166  23471.871094  23449.322266      23499.377781
# 167  23449.322266  23331.847656      23476.847459
# 168  23331.847656  22955.666016      23359.469262
# 169  22955.666016  22871.025391      22983.596356
#
# [170 rows x 3 columns]

# %%
actual_prices = unseen_predictions['Future_Price']
prediction_prices = unseen_predictions['prediction_label']
now = len(actual_prices)
from_days = 9


percent_error = abs((actual_prices[(now - from_days):] - prediction_prices[(now - from_days)]) / actual_prices[now - from_days]) * 100
avg_percent_error = percent_error.mean()
avg_percent_error = round(avg_percent_error, 1)

print(f"Average percent error: {avg_percent_error}%")
# Out:
# Average percent error: 1.399999976158142%
